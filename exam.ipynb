# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('exams.xlsx')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C                 high school      standard
# 1    female        group D          associate's degree      standard
# 2      male        group C                some college      standard
# 3      male        group D          associate's degree  free/reduced
# 4    female        group C           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group D          associate's degree      standard
# 996    male        group A           bachelor's degree      standard
# 997  female        group C          associate's degree  free/reduced
# 998    male        group B                 high school  free/reduced
# 999  female        group E                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 0                 completed          94             97             97
# 1                      none          78             83             81
# 2                 completed          89             79             81
# 3                      none          69             70             62
# 4                      none          73             88             90
# ..                      ...         ...            ...            ...
# 995                    none          74             69             75
# 996               completed          86             90             90
# 997               completed          57             71             73
# 998               completed          39             45             46
# 999               completed          71             80             81
#
# [1000 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     74
# reading score                  73
# writing score                  74
# dtype: int64

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.450000      69.447000      68.441000
# std      15.207721      14.793243      15.498604
# min      21.000000      20.000000      24.000000
# 25%      57.000000      60.000000      57.000000
# 50%      66.000000      69.000000      69.000000
# 75%      77.000000      80.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
numerical_features=[features for features in df.columns if df[features].dtypes!='O']

# %%
numerical_features
# Out:
# ['math score', 'reading score', 'writing score']

# %%
cat_features=[features for features in df.columns if df[features].dtypes=='O']

# %%
cat_features
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
df['total_score']=(df['math score']+df['reading score']+df['writing score'])

# %%
df['avg_score']=df['total_score']/3

# %%
df['avg_score'].min()
# Out:
# 27.0

# %%
fig,axis=plt.subplots(1,2,figsize=(15,17))
plt.subplot(121)
sns.histplot(data=df,x='avg_score',bins=30,kde=True)
plt.subplot(122)
sns.histplot(data=df,x='total_score',bins=30,kde=True,hue='gender')
# Out:
# <AxesSubplot: xlabel='total_score', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='avg_score',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='avg_score',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='avg_score',kde=True,hue='lunch')
# Out:
# <AxesSubplot: xlabel='avg_score', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='avg_score',kde=True,hue='parental level of education')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='avg_score',kde=True,hue='parental level of education')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='avg_score',kde=True,hue='parental level of education')
# Out:
# <AxesSubplot: xlabel='avg_score', ylabel='Count'>
